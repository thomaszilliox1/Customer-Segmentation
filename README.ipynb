# %% [markdown]
# ![Logo place de marché.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Résumé du projet

# %% [markdown]
# ## Contexte

# %% [markdown]
# Sur cette place de marché anglophone, des vendeurs proposent des articles à des acheteurs en postant une photo et une description.
# il devient nécessaire d'automatiser l'attribution de la catégorie des articles,
# pour rendre l’expérience utilisateur des vendeurs plus fluide.

# %% [markdown]
# ## Mission

# %% [markdown]
# Étudier la faisabilité d'un moteur de classification des articles en différentes catégories, à partir du texte (en anglais) et de l’image.

# %% [markdown]
# ## Méthodes utilisées

# %% [markdown]
# ### Classification grâce aux descriptions des articles :

# %% [markdown]
# + Méthodes classiques : Bag of Words et TF-IDF
# + Méthodes de Word Embedding :
#     - Word2Vec
#     - BERT : Tenserflow Hub et Hugging Face Transformers
#     - USE

# %% [markdown]
# Outils utilisés pour améliorer le score de prédiction : TSNE

# %% [markdown]
# ### Classification grâce aux images des articles

# %% [markdown]
# - Méthode SIFT : Non concluante
# - Méthode Conventionnal Neural Network : VGG16, VGG19 et ResNet 50

# %% [markdown]
# **Comparaison des résultats :**

# %% [markdown]
# ![Résultats classification Image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Mise en place d'une API

# %% [markdown]
# URL de l'API pour le produit "champagne" : https://api.edamam.com/api/food-database/v2/parser?app_id=99ac66db&app_key=1fc39dc71e1d27c4138d43442db37e9d&ingr=champagne&nutrition-type=cooking"
